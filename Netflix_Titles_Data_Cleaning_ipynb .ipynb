# %% [markdown]
# # Netflix Titles Data Cleaning

# %%
# libraries
import numpy as np
import pandas as pd

# %%
# Loading the Netflix dataset
df = pd.read_csv("netflix_titles.csv")

df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# # Question 1

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# The dataset contains 8807 rows and 12 columns.

# %% [markdown]
# # Question 2

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# The dataset is not complete because several columns contain missing values.
# From the analysis using df.isnull().sum(), the columns director, cast, country, date_added, rating, and duration contain missing values and the column with the highest number of missing values is director with 2634.

# %% [markdown]
# # Question 4

# %%
last20 = df.tail(20)
last20['type'].value_counts()
# Out:
# type
# Movie      15
# TV Show     5
# Name: count, dtype: int64

# %% [markdown]
# Among the last 20 rows of the dataset there are:
#
# 15 movies and 5 tv Shows

# %% [markdown]
# #Question 5

# %%
df[(df['country'] == 'South Africa') & (df['type'] == 'Movie')].shape[0]
# Out:
# 24

# %% [markdown]
# # Question 6

# %%
df.iloc[11]['description']
# Out:
# 'Struggling to earn a living in Bangkok, a man joins an emergency rescue service and realizes he must unravel a citywide conspiracy.'

# %% [markdown]
# # Question 7

# %%
df.query("country == 'South Africa' and release_year == 2021 and type == 'Movie'")
# Out:
#      show_id   type                         title       director  \
# 293     s294  Movie                          Slay      Adze Ugah
# 764     s765  Movie  Trippin' with the Kandasamys  Jayan Moodley
# 881     s882  Movie                I Am All Girls  Donovan Marsh
# 1172   s1173  Movie       Loyiso Gola: Unlearning  Kagiso Lediga
#
#                                                    cast       country  \
# 293   Enhle Mbali, Ramsey Nouah, Dawn Thandeka Kang,...  South Africa
# 764   Jailoshini Naidoo, Maeshni Naicker, Madhushan ...  South Africa
# 881   Erica Wessels, Hlubi Mboya, Deon Lotz, Brendon...  South Africa
# 1172                                        Loyiso Gola  South Africa
#
#           date_added  release_year rating duration  \
# 293   August 8, 2021          2021  TV-MA   86 min
# 764     June 4, 2021          2021  TV-14   94 min
# 881     May 14, 2021          2021  TV-MA  107 min
# 1172  March 23, 2021          2021  TV-MA   60 min
#
# ...

# %% [markdown]
# #Question 8

# %%
df.query("release_year == 2021 and type == 'Movie'")['cast']
# Out:
# 6       Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 9       Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12      Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 13      Klara Castanho, Lucca Picon, Júlia Gomes, Marc...
# 18      Freida Pinto, Logan Marshall-Green, Robert Joh...
#                               ...
# 1425                                                  NaN
# 1431    Engin Günaydın, Haluk Bilginer, Binnur Kaya, Ö...
# 1436    Juan Sebastián Gutiérrez, Pablo Cano, Pablo Me...
# 1466                                                  NaN
# 1468             Cha In-pyo, Cho Dal-hwan, Song Jae-ryong
# Name: cast, Length: 277, dtype: object

# %% [markdown]
# #group memmbers :
#
# Brian Mutuma - 153113
#
# Louis Gathu Wambui - 170417
#
# Allan kipkoech Tom - 133106
#
# Ahmed kowthar – 166069
#
# Mustafa  nour - 172235

# %% [markdown]
# ![5888992469330890068.jpg](data:image/jpeg;base64,...)
